# %% [markdown]
# ## Data Ingestion

# %%
# Document Structure
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Jonas Rocha",
        "date_created":"2026-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Jonas Rocha', 'date_created': '2026-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
# Create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
"../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
"""
}

for filepath,content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
# TextLoader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# Directory Loader
from langchain_community.document_loaders import DirectoryLoader

# load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", # Pattern to match files  
    loader_cls= TextLoader, # loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n'),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# Load PDF files
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

# load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", # Pattern to match files  
    loader_cls= PyMuPDFLoader, # loader class to use
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 0}, page_content='Understand\nyour setup\nLanguage support\nAgent Development Kit (ADK) supports multiple \nprogramming languages:\nPython 3.11+ (covered in this course)\nJava 17+ (see Java Quickstart)\nThis course uses Python for examples. The \nconcepts apply to all supported languages.\nBefore you begin, ensure you have:\nRequired software (Python)\nPython 3.11 or higher – ADK requires \u2028\nPython 3.11+\nCheck your version: \n \u2028\nor \nIf needed, download from python.org\npip – Python package installer \u2028\n(included with Python)\nVerify: \n or \u2028\nTerminal/command prompt – Access to \u2028\na command-line interface\nMac: Terminal app\nWindows: PowerShell or Command Prompt\nLinux: Your preferred terminal\nSystem compatibility\npython --version\npython3 --version\npip --version\npip3 --version\nmacOS\nWindows 10/11\nLinux (Ubuntu, Debian, Fedora, etc.)\nAssumptions\nThis guide assumes:\nYou have administrator/sudo access \u2028\nto install packages\nYou’re familiar with basic \u2028\nterminal commands\nYou can create and edit text files\nYou have internet connectivity for \u2028\npackage downloads\nNote: All commands in this guide show \u2028\nvariants for different operating systems \u2028\nwhere they differ.'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 1}, page_content='2\nShell\npython --version\nShell\nmkdir adk-workspace\ncd adk-workspace\nShell\npython3 --version\nExpected output: \n or higher \u2028\n(for example, \n)\nIf Python is not installed or the version \u2028\nis too old:\nDownload from python.org\nInstall Python 3.11 or newer\nRestart your terminal after installation\nRe-run the version check\nPython 3.11.x\nPython 3.12.0\nWhat this does:\nCreates a new directory called \nChanges into that directory\nKeeps all your agent projects organized \u2028\nin one place\nWindows users: These commands work \u2028\nin both PowerShell and Command Prompt.\nadk-workspace\nStep-by-step setup\nFollow these steps in order to set up your ADK development environment.\nStep 1: Verify Python installation\nFirst, check that you have Python 3.11 \u2028\nor higher installed.\nCheck Python version:\nStep 2: Create a workspace directory\nCreate a dedicated folder for your ADK projects:\nor'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 2}, page_content='3\nShell\npython -m venv .venv\nShell\npip install google-adk\nShell\nadk --version\nShell\nsource .venv/bin/activate\nShell\npython3 -m venv .venv\nNone\n.venv\\Scripts\\Activate.ps1\nNone\n.venv\\Scripts\\activate.bat\nWhat this does:\nCreates a folder called \n containing \u2028\nan isolated Python environment\nThis environment has its own Python \u2028\ninterpreter and package space\nActivate the virtual environment:\nOn Mac/Linux:\n.venv\nWhat this installs:\nThe ADK framework with agent abstractions \n(\n, \n, etc.)\nCLI tools (adk command)\nDependencies for working with Google’s \u2028\nGemini models\nVerify the installation:\nLlmAgent Runner\nExpected output: \u2028\nVersion number like \n or higher\nIf \n fails:\nCheck that your virtual environment is activated \n(you should see \n in prompt)\nTry deactivating and reactivating: \u2028\n then re-activate\nReinstall: \n1.0.0\nadk --version\n(.venv)\ndeactivate\npip install --force-reinstall \ngoogle-adk\nHow to tell it’s activated:\nYour terminal prompt should now show \u2028\nat the beginning\nExample: \u2028\nImportant: You must activate this virtual \nenvironment every time you open a new terminal \u2028\nto work on your agent projects.\n(.venv) \n(.venv) user@machine:~/adk-workspace$\nStep 3: Create a virtual environment\nA virtual environment isolates your project \ndependencies from your system Python installation, \npreventing conflicts between different projects.\nCreate the virtual environment:\nStep 4: Install ADK\nWith your virtual environment activated, \u2028\ninstall the ADK:\nIf \n doesn’t work, try:\npython\nOn Windows (PowerShell):\nOn Windows (Command Prompt):'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 3}, page_content='4\nSteps:\nVisit Google AI Studio\nSign in with your Google account\nClick Create API Key\nCopy the API key (it looks like \n)\nBenefits:\nQuick setup (just needs API key)\nFree tier available\nPerfect for development and learning\nAIzaSyC...\nBenefits:\nEnterprise-grade features\nBetter scaling and quotas\nProduction-ready security\nFor this course, we recommend option A \u2028\n(Google AI Studio) for simplicity.\nSteps:\nCreate a Google Cloud project \u2028\nif you don’t have one\nEnable the Vertex AI API\nInstall the gcloud CLI\nAuthenticate\nNote your Project ID (visible in Cloud Console)\nNote your Location (for example,\n)\n us-central1\nStep 5: Get your API key\nYour agent needs access to a large language \u2028\nmodel or LLM (the “Model” component from \u2028\ncourse 1). For this course, we’ll use Google’s \u2028\nGemini models.\nHere you have two options:\nOption A: \nGemini API via Google AI Studio \u2028\n(recommended for learning)\nThis is the simplest option for getting started.\nOption B: \nGemini via Google Cloud Vertex AI \u2028\n(for production)\nUse this option if you need enterprise features \u2028\nor are deploying to production.\nPrerequisites:\nGoogle Cloud account\nBilling enabled (free trial available)\nA Google Cloud project\n1\n1\n5\n2\n2\n6\n3\n3\n4\n4\nShell\ngcloud auth application-default login'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 4}, page_content='5\nStep 6: Create your first \u2028\nagent project\nADK provides a command to scaffold a new \u2028\nagent project with the correct structure.\nCreate the project:\nShell\nadk create my_first_agent\nShell\ncd my_first_agent\nNone\nmy_first_agent/\n├── agent.py\xa0 \xa0 \xa0 # Main agent code \n(you’ll edit this)\n├── __init__.py \xa0 # Python package \ninitialization\n└── .env\xa0 \xa0 \xa0 \xa0 \xa0 # Environment \nvariables (you’ll edit this next)\nPython\nfrom google.adk.agents.llm_agent import \nAgent\n\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model=’gemini-2.5-flash’,\n\xa0\xa0\xa0\xa0name=’root_agent’,\n\xa0\xa0\xa0\xa0description=’A helpful assistant \nagent.’,\n\xa0\xa0\xa0\xa0instruction=’You are a helpful \nassistant.’\n)\nWhat this creates:\nUnderstanding the files:\n\u200b\n This is where you’ll define \u2028\nyour agent using Python code. This file brings \ntogether the model, tools, and orchestration \ncomponents you learned about in course 1. \u2028\nIt contains your \n definition\n Python package initialization \u2028\nfile that imports your agent module. This is \nrequired for ADK to discover your agent\n A special file for storing sensitive \ninformation like API keys. ADK automatically \u2028\nloads this file, keeping secrets out of \u2028\nyour code\nNavigate into the project:\nagent.py:\nroot_agent\n__init__.py:\n.env:\nVerify the default agent code:\nOpen \n in your text editor. \u2028\nYou should see something like this:\nagent.py\nWhat this code does:\nImports the \n class from ADK\nCreates a \n(the main agent ADK looks for)\nConfigures it with:\nModel: \n \u2028\n(the LLM that powers reasoning)\nName: \n (required identifier)\nDescription: What the agent does \u2028\n(used in multi-agent systems)\nInstruction: How the agent should behave\nThis is a minimal working agent. In module 2, you’ll \nlearn to customize these parameters and add tools.\nNote: This course uses Python. If you’re working \u2028\nwith Java, see the Java Quickstart for Java-specific \nproject structure and setup.\nAgent\nroot_agent \u2028\ngemini-2.5-flash\nroot_agent'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 5}, page_content='6\nStep 7: Configure your API key\nNow configure the \n file with the API key \u2028\nyou obtained in step 5.\nOpen the \n file in your text editor.\nIf using Google AI Studio (option A):\nReplace the contents with:\n.env\n.env\nReplace \n with your \nactual API key from Google AI Studio.\nExample:\nyour-actual-api-key-here\nIf using Vertex AI (option B):\nReplace the contents with:\nReplace:\n\u200b\n with your \u2028\nGoogle Cloud Project ID\nwith your preferred location \u2028\n(if different)\nExample:\nyour-project-id\nus-central1 \nShell\nGOOGLE_GENAI_USE_VERTEXAI=0\nGOOGLE_API_KEY=your-actual-api-key-here\nShell\nGOOGLE_GENAI_USE_VERTEXAI=0\nGOOGLE_API_KEY=AIzaSyC4lW...\nShell\nGOOGLE_GENAI_USE_VERTEXAI=1\nGOOGLE_CLOUD_PROJECT=your-project-id\nGOOGLE_CLOUD_LOCATION=us-central1\nShell\nGOOGLE_GENAI_USE_VERTEXAI=1\nGOOGLE_CLOUD_PROJECT=my-agent-\nproject-123\nGOOGLE_CLOUD_LOCATION=us-central1\nImportant security note:\nNever commit the \n file to version control \n(Git)\nThe \nfile should be listed in \nAPI keys are sensitive credentials. \u2028\nTreat them like passwords\n.env\n.env \n.gitignore'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 6}, page_content='7\nStep 8: Verify your setup\nLet’s confirm everything works by running \u2028\nthe ADK web interface.\nStart the ADK web interface:\nShell\nadk web\nShell\nINFO: \xa0 \xa0 Started server process\nINFO: \xa0 \xa0 Waiting for application startup.\nINFO: \xa0 \xa0 Application startup complete.\nINFO: \xa0 \xa0 Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)\nExpected output:\nWhat this does:\nStarts a local web server at \u2028\nOpens a browser tab automatically\nProvides a visual interface to interact \u2028\nwith your agent\nSuccess indicators:\nNo error messages in the terminal \nBrowser opens to the ADK interface\nYou see the web UI with your agent name\nhttp://localhost:8000\nIf you see errors:\n“ModuleNotFoundError: \u2028\nNo module named  ’google.adk’”\nYour virtual environment isn’t activated\nFix: Re-activate with \u2028\n (Mac/Linux) \u2028\nor \n (Windows)\nsource .venv/bin/activate\n.venv\\Scripts\\Activate.ps1\n“Invalid API key” or authentication errors\nCheck that your .env file has the correct \u2028\nvariable names\nFor Google AI Studio: Use \n(NOT \n)\nEnsure no extra spaces around the = sign\nVerify that the API key is correct \u2028\n(copy-paste again from Google AI Studio)\n“Command ’adk’ not found”\nThe virtual environment is not activated, \u2028\nor ADK is not installed\nFix: Activate venv, and then run \u2028\nStop the web server: Press \nin your terminal \nto stop the server when you’re done testing.\nGOOGLE_API_KEY \nGEMINI_API_KEY\npip install google-adk\nCtrl+C'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 7}, page_content='8\nUnderstanding your setup\nLet’s connect what you just built to the concepts from course 1.\nThe three components in your environment\nRemember: Agent = model + tools + orchestration.\nCheck Python version:\nModel (configured in step 7)\nYour \nfile configures access to Gemini\nGemini is the LLM that provides reasoning and decision-making\nThis is the “brain” that understands language and makes choices\nTools (coming in module 3)\nFunctions your agent can call to take actions\nExamples: search the web, read files, and send emails\nThese bridge “knowing” to “doing”\nOrchestration (provided by ADK)\nThe framework that runs the agent loop\nManages: Perceive → think → act → check → repeat\nYou installed this in step 4 (\n)\n.env \npip install google-adk\nHow the files work together\nagent.py – Where everything connects:\nYou saw the default agent code in step 6. Let’s connect it to course 1 concepts:\nShell\nfrom google.adk.agents.llm_agent import Agent\n\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model=’gemini-2.5-flash’,\xa0 \xa0 \xa0 \xa0 # Model: The reasoning engine (Course 1!)\n\xa0\xa0\xa0\xa0name=’root_agent’, \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 # Identity: Required identifier\n\xa0\xa0\xa0\xa0description=’A helpful agent.’,\xa0 # Purpose: What this agent does\n\xa0\xa0\xa0\xa0instruction=’You are helpful.’ \xa0 # Behavior: How to act\n\xa0\xa0\xa0\xa0# Tools: You’ll add these in Module 3\n\xa0\xa0\xa0\xa0# Orchestration: Handled automatically by the Agent class\n)'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:17:07+00:00', 'source': '..\\data\\pdf\\1-understand-your-setup.pdf', 'file_path': '..\\data\\pdf\\1-understand-your-setup.pdf', 'total_pages': 9, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:17:07+00:00', 'trapped': '', 'modDate': 'D:20251217041707Z', 'creationDate': 'D:20251217041707Z', 'page': 8}, page_content='9\nBreaking it down:\nModel (\n): The LLM that \nprovides reasoning and decision-making\nTools (not shown yet): Functions the agent calls \u2028\nto take actions (module 3)\nOrchestration: The Agent class automatically \u2028\nruns the Perceive → Think → Act → Check loop\n – Secure credentials:\nKeeps API keys out of code\nAutomatically loaded by ADK\nNever committed to Git\n – Package initialization:\nMakes your folder a Python package\nImports your agent module\nRequired for ADK to discover agents\nNote: ADK also supports YAML-based configuration \n(see Agent Config) and Java (see Java Quickstart). \nThis course focuses on Python code-based agents.\ngemini-2.5-flash\n.env\n__init__.py\nThe development workflow\nEdit \n – Define your agent’s behavior\nRun \n – Test in the web interface\nIterate – Make changes, refresh, and test again\nIterate – Make changes, refresh, and test again\nadk run – Terminal-based interaction\nadk api_server – Deploy as an API service\nagent.py\nadk web'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:20:16+00:00', 'source': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'file_path': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:20:16+00:00', 'trapped': '', 'modDate': 'D:20251217042016Z', 'creationDate': 'D:20251217042016Z', 'page': 0}, page_content="Define your\nagent's identity\nThis module builds on:\nYour working agent environment from module 1\nThe default agent code created by \nUnderstanding that \u2028\nmodel + tools + orchestration = agent\nadk create\nUnderstand your first agent\nIn module 1, you created a working agent using \n \u2028\nWhen you opened \n, you saw this code:\nadk create.\nagent.py\nYou verified it works with \n. It’s a success. \nBut what do these parameters actually mean? And how can you customize \u2028\nthis agent for specific tasks? Think of this module as understanding the \u2028\n“Model” component from course 1, which is the reasoning brain of your agent.\nadk web\nPython\nfrom google.adk.agents.llm_agent import Agent\n\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model='gemini-2.5-flash',\n\xa0\xa0\xa0\xa0name='root_agent',\n\xa0\xa0\xa0\xa0description='A helpful assistant agent.',\n\xa0\xa0\xa0\xa0instruction='You are a helpful assistant.'\n)"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:20:16+00:00', 'source': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'file_path': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:20:16+00:00', 'trapped': '', 'modDate': 'D:20251217042016Z', 'creationDate': 'D:20251217042016Z', 'page': 1}, page_content="The four core parameters\nReference: ADK docs – LLM Agent: Defining the \nAgent’s Identity and Purpose\nEvery \n (also imported as \n) \u2028\nis defined by four core parameters. Let’s explore \neach one.\nLlmAgent\nAgent\n1. \n (required)\nWhat it is: The underlying large language model \n(LLM) that powers your agent’s reasoning \u2028\nand decision-making.\nExample:\nmodel\n2. \n (required)\nWhat it is: A unique string identifier for your agent.\nExample:\nname\nPython\nmodel='gemini-2.5-flash'\nPython\nname='root_agent'\nWhat this does:\nDetermines your agent’s intelligence \u2028\nand capabilities\nAffects cost per request and response speed\nDifferent models have different strengths \u2028\n(speed versus capability)\nAvailable models:\n\u200b\n – Fast, efficient, \u2028\nand good for most tasks\n – More capable \u2028\nand better for complex reasoning\nSee models documentation for the full list\nAnalogy: Like choosing the engine for your car, \u2028\nmore powerful engines can handle more complex \ntasks but may cost more to run.\nImportant: This is a required parameter. \u2028\nYour agent cannot function without \u2028\nspecifying a model.\ngemini-2.5-flash\ngemini-2.5-pro\nWhat this does:\nIdentifies your agent internally within ADK\nCritical in multi-agent systems where agents \nrefer to each other\nUsed for logging, debugging, and agent \ndelegation\nNaming conventions:\nUse lowercase with underscores:   \u2028\nBe descriptive: \u2028\n, \nAvoid reserved names: \nDon't use camelCase: \u2028\nUse \nnot \nFrom ADK docs:\n“Every agent needs a unique string identifier. \u2028\nThis name is crucial for internal operations, especially \nin multi-agent systems, where agents need to refer \nto or delegate tasks to each other.”\nImportant: This is a required parameter. \u2028\nEvery agent must have a name.\ncustomer_support_agent\ndata_analysis_agent math_tutor_agent\nuser\nmy_agent \nmyAgent\n2"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:20:16+00:00', 'source': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'file_path': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:20:16+00:00', 'trapped': '', 'modDate': 'D:20251217042016Z', 'creationDate': 'D:20251217042016Z', 'page': 2}, page_content='3. \n (optional, \nrecommended for multi-agent)\nWhat it is: A concise summary of what \u2028\nyour agent does.\nExample:\ndescription\n4. \n \u2028\n(critical but optional)\nWhat it is: The behavioral blueprint that guides \u2028\nhow your agent acts and responds.\nExample:\ninstruction\nPython\ndescription=\'Answers user questions \nabout the capital city of a given \ncountry.\'\nPython\ninstruction="""You are a helpful \nassistant that tells the current time \nin cities.\nUse the \'get_current_time\' tool for \nthis purpose."""\nWhat this does:\nUsed by other agents to decide \u2028\nif they should route tasks to this agent\nHelps in multi-agent systems where agents \ndelegate to each other\nNot used by the agent itself for its own behavior\nFrom ADK docs:\n“This description is primarily used by other \u2028\nLLM agents to determine if they should route \u2028\na task to this agent. Make it specific enough \u2028\nto differentiate it from peers.”\nWhen to use:\nBuilding multi-agent systems with delegation\nAgents that will be called by other agents\nLess important for single-agent applications\nGood descriptions:\n“Handles customer billing inquiries \u2028\nand processes payment updates”\n“Analyzes sales data and generates weekly \u2028\nperformance reports”\n“Helps students learn algebra by guiding \u2028\nthem through problem-solving steps”\n“Billing agent” (too vague)\n“Helper” (not specific enough)\nWhat this does:\nDefines the agent’s personality \u2028\nand communication style\nSpecifies the agent’s core task or goal\nSets boundaries and constraints on behavior\nGuides when and how to use tools \u2028\n(covered in module 3)\nShapes the output format\nFrom ADK docs:\n“The instruction parameter is arguably the most \ncritical for shaping an LlmAgent’s behavior. It tells the \nagent its core task or goal, its personality or persona, \nconstraints on its behavior, and how and when to use \nits tools.”\nTips for effective instructions (from ADK docs):\nBe clear and specific: avoid ambiguity, clearly \nstate the desired actions and outcomes\nUse markdown: Improve readability for complex \ninstructions using headings, lists, etc.\nProvide examples (few-shot): For complex tasks \nor specific output formats, include examples\nGuide tool use: don’t just list tools, explain when \nand why the agent should use them\n3'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:20:16+00:00', 'source': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'file_path': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:20:16+00:00', 'trapped': '', 'modDate': 'D:20251217042016Z', 'creationDate': 'D:20251217042016Z', 'page': 3}, page_content='description\ninstruction\n versus \n – The key difference\nThis is critical to understand:\n4\nParameter\nAudience\nPurpose\nExample\ndescription\nOther agents\n“Should I route this task here?”\n“Handles billing inquiries”\ninstruction\nThis agent\n“How should I behave?”\n“You are a billing expert who…”\nConcrete example:\nPython\n# Multi-agent system with 3 agents\nbilling_agent = Agent(\n\xa0\xa0\xa0\xa0model=\'gemini-2.5-flash\',\n\xa0\xa0\xa0\xa0name=\'billing_agent\',\n\xa0\xa0\xa0\xa0# OTHER agents read this to decide if they should delegate here\n\xa0\xa0\xa0\xa0description=\'Handles customer billing inquiries and payment processing\',\n\xa0\xa0\xa0\xa0# THIS agent reads this to know how to behave\n\xa0\xa0\xa0\xa0instruction="""You are a billing specialist.\n\n\xa0\xa0\xa0\xa0When helping customers:\n\xa0\xa0\xa0\xa01. Be empathetic and patient\n\xa0\xa0\xa0\xa02. Explain charges clearly\n\xa0\xa0\xa0\xa03. Use the billing_lookup tool to check account details\n\xa0\xa0\xa0\xa04. Never promise refunds without manager approval\n\n\xa0\xa0\xa0\xa0Always maintain a professional, helpful tone."""\n)\n\nsupport_agent = Agent(\n\xa0\xa0\xa0\xa0model=\'gemini-2.5-flash\',\n\xa0\xa0\xa0\xa0name=\'support_agent\',\n\xa0\xa0\xa0\xa0description=\'Handles general customer support questions\',\n\xa0\xa0\xa0\xa0instruction="""You are a customer support agent.\n\n\xa0\xa0\xa0\xa0If a question is about billing, transfer to the billing_agent.\n\xa0\xa0\xa0\xa0Otherwise, help the customer directly."""\n)\nIn this example:\n\u200b\n reads \n\'s description to decide: “Is this a billing question?”\n reads its own instruction to know: “How do I handle billing questions?”\nsupport_agent\nbilling_agent\nbilling_agent'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:20:16+00:00', 'source': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'file_path': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:20:16+00:00', 'trapped': '', 'modDate': 'D:20251217042016Z', 'creationDate': 'D:20251217042016Z', 'page': 4}, page_content="The \n naming convention\nReference: Python Quickstart for ADK\nYou might have noticed your agent variable is named \n:\nroot_agent\nroot_agent\n5\nPython\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model='gemini-2.5-flash',\n\xa0\xa0\xa0\xa0name='root_agent',\xa0 # Internal name (inside Agent)\n\xa0\xa0\xa0\xa0# ...\n)\nPython\n# Internal ADK name (used for logging, delegation)\nmy_specialized_agent = Agent(\n\xa0\xa0\xa0\xa0model='gemini-2.5-flash',\n\xa0\xa0\xa0\xa0name='math_tutor_agent',\xa0 # Used by ADK internally\n\xa0\xa0\xa0\xa0description='Helps students with algebra',\n\xa0\xa0\xa0\xa0instruction='You are a patient math tutor...'\n)\n\n# Variable name that ADK tools look for (must be root_agent)\nroot_agent = my_specialized_agent\nWhy root_agent?\nADK command-line tools look for a Python variable named root_agent as the entry point to your agent \nsystem. This is a convention that allows ADK to discover and run your agent.\nFrom ADK docs:\n“The agent.py file contains a root_agent definition, which is the only required element of an ADK agent.”\nCan the internal name be different from the variable name?\nYes. The \n parameter inside \n is separate from the variable name:\nname\nAgent()\nKey rule: Always assign your main agent to a variable named \n, so ADK tools can find it.\nIn module 3, you’ll learn how ADK tools use root_agent to run your agent in different ways.\nroot_agent"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:20:16+00:00', 'source': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'file_path': '..\\data\\pdf\\2-define-your-agests-identity.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:20:16+00:00', 'trapped': '', 'modDate': 'D:20251217042016Z', 'creationDate': 'D:20251217042016Z', 'page': 5}, page_content='Writing effective instructions\nReference: ADK docs – Guiding the Agent: Instructions\nInstructions guide your agent’s behavior and personality. \u2028\nFor this course, we’ll keep them simple to help you understand the basics.\nSimple approach for course 2:\n6\nPython\ninstruction="You are a patient math tutor. Help students with algebra problems."\nThis basic instruction is enough to get started. It tells the agent:\nIts role (math tutor)\nIts personality trait (patient)\nIts task (help with algebra)\nDo you want to learn professional instruction patterns? In course 3: \u2028\nCrafting Better Agent Behavior, you’ll learn advanced techniques, including:\nMulti-section instruction structures\nPersona and boundary definitions\nFew-shot examples\nProduction-ready instruction patterns\nFor now, let’s focus on understanding how basic instructions work.'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:21:06+00:00', 'source': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'file_path': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:21:06+00:00', 'trapped': '', 'modDate': 'D:20251217042106Z', 'creationDate': 'D:20251217042106Z', 'page': 0}, page_content="Hands-on:\nTransform your agent\nLet’s take the default agent from module 1 \u2028\nand transform it into a specialized math tutor.\nStarting point (module 1 default)\nStep 1: Update the internal name\nMake the name more descriptive for what this agent actually does:\nPython\nfrom google.adk.agents.llm_agent import Agent\n\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model='gemini-2.5-flash',\n\xa0\xa0\xa0\xa0name='root_agent',\n\xa0\xa0\xa0\xa0description='A helpful assistant agent.',\n\xa0\xa0\xa0\xa0instruction='You are a helpful assistant.'\n)\nPython\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model='gemini-2.5-flash',\n\xa0\xa0\xa0\xa0name='math_tutor_agent',\xa0 # More specific internal name\n\xa0\xa0\xa0\xa0description='A helpful assistant agent.',\n\xa0\xa0\xa0\xa0instruction='You are a helpful assistant.'\n)"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:21:06+00:00', 'source': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'file_path': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:21:06+00:00', 'trapped': '', 'modDate': 'D:20251217042106Z', 'creationDate': 'D:20251217042106Z', 'page': 1}, page_content="Step 2: Write a specific description\nRemember: description tells other agents what this agent does (important for multi-agent systems).\nStep 3: Write a simple instruction\nRemember: \n tells this agent how to behave and respond.\ninstruction\nPython\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model='gemini-2.5-flash',\n\xa0\xa0\xa0\xa0name='math_tutor_agent',\n\xa0\xa0\xa0\xa0description='Helps students learn algebra by guiding them through problem-\nsolving steps.',\n\xa0\xa0\xa0\xa0instruction='You are a helpful assistant.'\n)\nPython\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model='gemini-2.5-flash',\n\xa0\xa0\xa0\xa0name='math_tutor_agent',\n\xa0\xa0\xa0\xa0description='Helps students learn algebra by guiding them through problem-\nsolving steps.',\n\xa0\xa0\xa0\xa0instruction='You are a patient math tutor. Help students with algebra problems.'\n)\n2\nWhat changed: Other agents can now understand this is specifically \u2028\nfor algebra tutoring, not general questions.\nWhat this instruction does:\nDefines the agent’s role (math tutor)\nSets the personality (patient)\nSpecifies the task (help with algebra)\nNote: This simple instruction is perfect for learning the basics. In course 3, you’ll learn \u2028\nhow to write production-ready instructions with detailed persona, boundaries, and examples."),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:21:06+00:00', 'source': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'file_path': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:21:06+00:00', 'trapped': '', 'modDate': 'D:20251217042106Z', 'creationDate': 'D:20251217042106Z', 'page': 2}, page_content="Complete transformed agent\nPython\nfrom google.adk.agents.llm_agent import Agent\n\nroot_agent = Agent(\n\xa0\xa0\xa0\xa0model='gemini-2.5-flash',\n\xa0\xa0\xa0\xa0name='math_tutor_agent',\n\xa0\xa0\xa0\xa0description='Helps students learn algebra by guiding them through problem-\nsolving steps.',\n\xa0\xa0\xa0\xa0instruction='You are a patient math tutor. Help students with algebra problems.'\n)\n3\nSave this to your \n file in your \n directory from module 1.\nThis simple agent demonstrates:\nSpecific role definition (math tutor)\nClear personality (patient)\nDefined task scope (algebra problems)\nAre you ready for more? \nCourse 3 will teach you how to enhance this with professional \u2028\ninstruction patterns, boundaries, and examples for production use.\nagent.py\nmy_first_agent"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:21:06+00:00', 'source': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'file_path': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:21:06+00:00', 'trapped': '', 'modDate': 'D:20251217042106Z', 'creationDate': 'D:20251217042106Z', 'page': 3}, page_content='4\nTest your customized agent\nReference: ADK docs – Python Quickstart: Interacting with Your Agent\nNow, let’s see your customized math tutor agent in action using the ADK web interface.\nStep 1: Start the web interface\nFrom your \n directory (or the parent directory containing it), run:\nmy_first_agent\nShell\nadk web\nExpected output:\nNone\nINFO: \xa0 \xa0 Started server process\nINFO: \xa0 \xa0 Waiting for application startup.\nINFO: \xa0 \xa0 Application startup complete.\nINFO: \xa0 \xa0 Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)\nWhat this does:\nStarts a local development server at \nAutomatically opens your browser to the ADK web interface\nLoads your customized \nfrom \nFrom ADK docs:\n“You can start the web interface using the following command: adk web. \u2028\nThis command starts a web server with a chat interface for your agent.”\nhttp://localhost:8000\nmath_tutor_agent \nagent.py'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:21:06+00:00', 'source': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'file_path': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:21:06+00:00', 'trapped': '', 'modDate': 'D:20251217042106Z', 'creationDate': 'D:20251217042106Z', 'page': 4}, page_content="Step 2: Interact with your math tutor\nOnce the web interface opens:\nSelect your agent from the dropdown \u2028\n(it should show your agent’s \n)\nTry the following test questions to see \u2028\nhow your customized instructions work:\nExample interactions:\nQuestion: “What is 2x + 5 = 13?”\nExpected behavior: Your agent should:\nAct as a math tutor\nHelp with the problem\nDemonstrate a patient tone\nQuestion: “I don’t understand algebra at all.”\nExpected behavior: Your agent should:\nRespond as a patient tutor\nOffer help with algebra concepts\nMaintain a supportive approach\nname\nStep 4: Stop the server\nWhen you’re done testing:\nPress \n in the terminal \u2028\nto stop the web server\nTroubleshooting:\nIf the agent doesn’t appear in the dropdown:\nMake sure you’re running \nfrom the parent directory of \nOr run adk web my_first_agent \u2028\nto specify the path\nIf you see the old generic responses:\nMake sure you saved the changes to \nStop the server (\n), and restart \nThe server needs to be restarted \u2028\nto pick up code changes\nCtrl+C\nadk web \u2028\nmy_first_agent\nagent.py\nCtrl+C\nadk web\nGeneric responses\nNo specific domain expertise\nF ocused on math tutoring\nPatient approach to teaching\nSpecialized for algebra help\nThis demonstrates how even simple, focused \ninstructions can significantly improve agent behavior.\n5\nStep 3: Observe the difference\nCompare your customized agent’s responses \u2028\nto the generic “You are a helpful assistant” \ninstruction from module 1.\nGeneric agent (module 1):\nCustomized math tutor (module 2):\nPython\ninstruction='You are a helpful \nassistant.'\nPython\ninstruction='You are a patient math \ntutor. Help students with algebra \nproblems.'"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-12-17T04:21:06+00:00', 'source': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'file_path': '..\\data\\pdf\\3-handson-transform-your-agent.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-17T04:21:06+00:00', 'trapped': '', 'modDate': 'D:20251217042106Z', 'creationDate': 'D:20251217042106Z', 'page': 5}, page_content='6\nKey takeaways\nRequired parameters:\nOnly \n and \n are technically required\nBut \n is critical for useful behavior\n is important for multi-agent systems\nBest practices for course 2:\nWrite simple, focused instructions that define the role and task\nBe specific about what the agent does (don’t just “be helpful”)\nInclude a personality trait to guide the tone\nTest with \n to see how instructions affect behavior\nCommon pitfalls:\nVague instructions, like “be helpful”\nConfusing \n with \nForgetting to assign to \n variable\nUsing unclear or generic names\nmodel\nname\ninstruction\ndescription\nadk web\ndescription\ninstruction\nroot_agent\nNext level: For production-ready agents, course 3 \u2028\nteaches advanced instruction patterns, including \u2028\nmulti-section structures, boundaries, and few-shot examples.')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
