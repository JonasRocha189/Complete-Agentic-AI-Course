# %% [markdown]
# # Models Integration with OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ## OpenAI Model Integration

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.0', 'langchain': '1.3.16', 'langchain-openai': '1.6.0'}}, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x00000261CA2E4190>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000261CAD09250>, root_client=<openai.OpenAI object at 0x00000261CA2CFE90>, root_async_client=<openai.AsyncOpenAI object at 0x00000261CAD08DD0>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
# invoke the model
response = model.invoke("Hello, how are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a bunch of code, but I'm ready to help you. How can I assist you today? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 13, 'total_tokens': 37, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_2625cfc357', 'id': 'chatcmpl-EFMayXIjRJbqELAi3YuTinmPMTJ6U', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02532-d3b8-7b23-af69-0eae9951b4fe-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 24, 'total_tokens': 37, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# "Hello! I'm just a bunch of code, but I'm ready to help you. How can I assist you today? 😊"

# %%
### ChatOpenAI

from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4.1")
response = model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm here and ready to help. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 12, 'total_tokens': 28, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_c935aef436', 'id': 'chatcmpl-EFMb0XrdzGB7wCQMPtdoQZTt28vH9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02532-dcdb-7b22-b538-377cacf9d55e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 16, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-3.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text',
#   'text': 'Parrots talk because of a fascinating combination of **anatomy, social behavior, and high intelligence**. Unlike humans, parrots don’t have vocal cords; instead, they use an organ called the **syrinx** located at the bottom of their trachea to manipulate airflow and mimic sounds. \n\nHere is a breakdown of the primary reasons *why* they do it:\n\n### 1. Social Bonding and Flocking\nIn the wild, parrots are extremely social, flock-dwelling birds. To survive, they need to communicate constantly with their family members to signal danger, find food, and recognize one another. \n* **Flock Dialects:** Different flocks of parrots actually develop their own unique "dialects" or accents. \n* **Human as Flock:** When a parrot lives in a human home, it views its human family as its flock. Because parrots naturally try to fit in with their flock, they mimic human speech to bond and communicate with us.\n\n### 2. High Intelligence and Problem-Solving\nParrots have brains that are remarkably large for their body size, particularly a part of the brain called the *nidopallium*, which is thought to be responsible for complex cognitive tasks (similar to the human prefrontal cortex). \n* They are natural problem-solvers and quickly realize that making a specific sound (like saying "Treat!" or "Hello!") gets them a predictable, desirable result (like getting food or attention).\n\n### 3. Attention Seeking\nParrots quickly learn cause and effect. If a parrot says "Hello!" and the owner turns around, laughs, or gives it a snack, the parrot learns: *“When I make this sound, humans pay attention to me.”* Even negative reactions—like yelling "Stop that!"—can reinforce the behavior because, to the parrot, any attention is better than being ignored.\n\n### 4. Environmental Stimulation and Boredom\nWild parrots are constantly stimulated by sights, sounds, and challenges. Pet parrots, however, can sometimes experience boredom. Talking is a way to keep themselves entertained. This is why parrots often talk to themselves, the TV, or even inanimate objects when no one is in the room.\n\n### 5. Play and Joy\nParrots simply seem to enjoy the sound of their own voices. They will practice words, experiment with pitches, and babble just like human toddlers do. It is a form of play and self-amusement.\n\n---\n\n### Fun Fact: Do they know what they are saying?\nWhile many parrots just mimic sounds without understanding them, some—most famously an African Grey parrot named **Alex**, studied by Dr. Irene Pepperberg—demonstrated the ability to use human words in context. Alex could correctly identify colors, shapes, and numbers, proving that at least some parrots understand the underlying meanings of the words they speak!',
#   'extras': {'signature': 'El4KXAERTTIPykhuA1cWEctyqB6YuqiGl0mi/+yTz3jpsn4dHiY3fvA3RCJQ7dlgIcW9+Gd+9Gyj9jONIBuJL9uxtEDx/+KeBjZieR5so6gZKMqPa86cYlF+hQht4yIc'}}]

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots talk primarily because they are **social learners** and **vocal mimics**. In the wild, their ability to learn and replicate sounds is a crucial survival tool. \n\nHere is a breakdown of why parrots talk, both in the wild and in human homes:\n\n### 1. Social Bonding and Flocking (In the Wild)\nParrots are extremely social, flock-dwelling birds. In the wild, a flock is a parrot’s family and protection. To fit in, babies must learn the exact vocalizations (calls, whistles, and squawks) of their specific flock. \n* **Dialects:** Different flocks of the same species often have different "dialects." \n* **Identity:** Parrots use unique contact calls to identify mates, family members, and signal where food is. If a parrot doesn\'t sound like the rest of the flock, it risks being ostracized.\n\n### 2. High Intelligence and Brain Structure\nParrots have remarkably large forebrains, which are associated with higher cognitive functions. They also possess a vocal organ called a **syrinx**, which allows them to manipulate airflow and produce a vast range of complex sounds (unlike humans, who use lips, teeth, and a tongue, parrots use muscles in their throat to shape sound). \n\n### 3. Fulfilling the Need for Social Interaction (As Pets)\nWhen a parrot lives with humans, **humans become its flock**. Because parrots are hardwired to blend in with their social group, they try to learn the language of their "flockmates." When a parrot talks to you, it is essentially trying to communicate, connect, and bond with you.\n\n### 4. Attention and Reward\nParrots quickly learn that human speech yields big results. If a parrot yells "Hello!" or mimics the microwave beep and someone comes running, gives them attention, or offers a treat, the parrot learns: *“When I make that sound, wonderful things happen.”* They use human words to request food, toys, or simply to get noticed.\n\n### 5. Boredom and Environmental Stimulation\nParrots are intelligent creatures that need mental stimulation. If they are bored, they may practice mimicking sounds in their environment just to pass the time. This is why many parrots learn to mimic the squeaky door, the barking dog, the phone ringing, or the sound of water dripping.\n\n### Summary\nIn short, parrots don’t talk because they understand human language the way we do (though some can learn to associate words with meanings). **They talk because they are biologically programmed to copy the sounds of their social group in order to connect, survive, and get what they need.**', 'extras': {'signature': 'El4KXAERTTIPodcTJZ6SUaSd20ia6LX9ov6Bxpp0x3U3kOPMSEExLd7RQTTEOIcB+JcAZzqnqlCMPnF+FRZttUOxMzdgvhxM9Z/NWq1MYUPUdzLhnyCW6sguE0jPn1fX'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a02532-f4da-7893-90e8-46a3e93a8b84-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 552, 'total_tokens': 558, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# ## Groq Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

# %%
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3.6-27b")
#model = init_chat_model("groq:openai/gpt-oss-20b")
response = model.invoke("What is the capital of France?")
response.content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - Question: "What is the capital of France?"\n   - Key entity: France\n   - Target information: Capital city\n\n2.  **Identify Core Knowledge:**\n   - France is a country in Western Europe.\n   - Its capital city is Paris.\n   - This is a well-established, universally recognized fact.\n\n3.  **Formulate Response:**\n   - Keep it direct and accurate.\n   - "The capital of France is Paris."\n\n4.  **Self-Correction/Verification:**\n   - Is there any ambiguity? No.\n   - Is it up-to-date? Yes, Paris has been the capital for centuries.\n   - Any trick? No.\n   - Response matches factual knowledge.\n\n5.  **Output Generation:**\n   - "The capital of France is Paris."✅\n</think>\n\nThe capital of France is Paris.'

# %%
import os 
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3.6-27b")
response = model.invoke("What is the capital of France?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - Question: "What is the capital of France?"\n   - This is a straightforward, factual geography question.\n\n2.  **Identify Key Entity:**\n   - Country: France\n   - Query: Capital city\n\n3.  **Retrieve Knowledge:**\n   - From general knowledge: The capital of France is Paris.\n   - Verify: This is a well-established, universally recognized fact.\n\n4.  **Formulate Response:**\n   - Keep it direct and accurate.\n   - Response: "The capital of France is Paris."\n\n5.  **Final Check:**\n   - Does it answer the question? Yes.\n   - Is it accurate? Yes.\n   - Is it concise? Yes.\n   - Ready.✅\n</think>\n\nThe capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 186, 'prompt_tokens': 17, 'total_tokens': 203, 'completion_time': 0.423585183, 'completion_tokens_details': None, 'prompt_time': 0.001145399, 'prompt_tokens_details': None, 'queue_time': 0.003867962, 'total_time': 0.424730582}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_b545673577', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0253e-6297-70b2-8fc5-fbb7c98e8476-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 186, 'total_tokens': 203})

# %% [markdown]
# ## Streaming and Batch

# %% [markdown]
# ### Streaming
#
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model = ChatGroq(model="allam-2-7b")

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) has become a rapidly evolving and influential field in our modern world. This groundbreaking technological advancement refers to the simulation of human intelligence and decision-making processes in machines. AI encompasses a wide range of applications and disciplines, including but not limited to machine learning, natural language processing, robotics, and cognitive systems.\n\nOne of the primary goals of AI is to develop intelligent machines capable of autonomous decision-making, learning from experience, and adapting to new situations. This is achieved through the development of algorithms that enable machines to analyze data, identify patterns, and make predictions or recommendations. AI systems can be trained on vast amounts of data, allowing them to improve their performance over time, a concept known as machine learning.\n\nOne of the most significant applications of AI is in the field of data analysis and predictive modeling. With the increasing volume and complexity of data available today, AI systems can help businesses and organizations make more informed decisions by identifying trends, patterns, and correlations within data sets. This can lead to better forecasting, optimization, and resource allocation.\n\nAI has also revolutionized the field of healthcare by enabling more accurate diagnoses, drug discovery, and personalized treatment plans. Machine learning algorithms can analyze vast amounts of medical data to identify potential health risks, predict outcomes, and develop tailored treatments for individual patients.\n\nIn addition, AI is playing an increasingly important role in various industries such as transportation, where self-driving cars and autonomous systems are being developed. These systems have the potential to improve safety, reduce human error, and optimize traffic flow.\n\nHowever, as AI continues to advance, it raises important ethical and societal concerns. The development of intelligent machines raises questions about employment opportunities, privacy, and the potential for AI to replicate biases and discrimination. It is crucial that researchers, developers, and policymakers work together to ensure the responsible development and deployment of AI to minimize these potential negative impacts and maximize its benefits for society.\n\nIn conclusion, AI is shaping our world in remarkable ways, offering unprecedented advancements in various fields, from healthcare to transportation and beyond. While the future of AI holds enormous potential, it is essential to address the challenges and ensure that its development and deployment align with our values and goals for a better society. ', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 476, 'prompt_tokens': 20, 'total_tokens': 496, 'completion_time': 0.342307045, 'completion_tokens_details': None, 'prompt_time': 0.001193905, 'prompt_tokens_details': None, 'queue_time': 0.207319426, 'total_time': 0.34350095}, 'model_name': 'allam-2-7b', 'system_fingerprint': 'fp_ff744b2c7a', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a02543-2720-70f1-8834-0661175d1780-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 476, 'total_tokens': 496})

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Art|ificial| Intelligence|,| or| AI| for| short|,| refers| to| the| development| of| computer| systems| and| machines| that| possess| the| ability| to| perform| tasks| that| typically| require| human| intelligence|.| These| tasks| include| problem|-|sol|ving|,| decision|-|making|,| learning|,| and| understanding| complex| data|.| AI| has| become| an| essential| field| in| the| realm| of| technology|,| with| significant| advance|ments| sh|aping| various| aspects| of| our| lives|.|
# |
# |The| history| of| AI| dates| back| to| the| early| |1|9|5|0|s| when| ren|owned| scientists| like| Alan| T|uring| and| John| McC|arth|y| started| discussing| the| concept| of| machines| capable| of| mim|icking| human| thinking|.| Over| the| years|,| AI| has| prog|ressed| through| various| stages|,| starting| with| rule|-|based| systems|,| which| relied| on| pred|ef|ined| rules| and| logic| to| perform| tasks|.| Later|,| AI| evolved| into| machine| learning|,| a| technique| that| enables| machines| to| learn| from| data| and| improve| their| performance| over| time|.| Modern| AI| involves| deep| learning|,| a| sub|field| that| uses| artificial| neural| networks| to| sim|ulate| the| human| brain|'|s| neural| structure| and| enable| machines| to| recognize| patterns| and| make| decisions|.|
# |
# |AI| has| numerous| applications|,| including| but| not| limited| to|:|
# |
# |1|.| Rob|otics|:| AI| enables| robots| to| perform| tasks| auton|om|ously|,| from| simple| repet|itive| actions| to| complex| tasks| like| navigation|,| assembly|,| and| even| social| interaction|.|
# |2|.| Int|ellig|ent| assist|ants|:| AI|-|powered| virtual| assist|ants|,| like| Sir|i|,| Alex|a|,| and| Google| Assistant|,| help| users| perform| tasks|,| answer| questions|,| and| provide| information| through| natural| language| processing|.|
# |3|.| Int|ellig|ent| agents|:| AI|-|powered| chat|b|ots| and| decision|-|making| systems| are| used| in| customer| service|,| business| processes|,| and| even| healthcare| to| improve| efficiency| and| provide| personal|ized| assistance|.|
# |4|.| Image| and| speech| recognition|:| AI|-|powered| algorithms| can| identify| objects|,| people|,| and| emotions| in| images| and| recognize| human| speech|,| enabling| communication| and| interaction| between| humans| and| machines|.|
# |5|.| Pred|ict|ive| analy|tics|:| AI| is| used| in| industries| like| finance|,| marketing|,| and| healthcare| to| analyze| data|,| identify| patterns|,| and| make| predictions| to| improve| decision|-|making| processes|.|
# |6|.| Aut|on|omous| vehicles|:| AI| plays| a| crucial| role| in| developing| self|-|d|riving| cars|,| enabling| them| to| navigate| roads|,| recognize| obstacles|,| and| adapt| to| changing| conditions|.|
# |
# |With| the| continuous| advance|ments| in| AI| technology|,| we| can| expect| to| see| more| sophisticated| applications| in| the| near| future|.| As| AI| systems| become| sm|arter|,| they| hold| great| potential| for| enhancing| human| productivity|,| enabling| innovation|,| and| improving| our| quality| of| life|.| However|,| it| is| crucial| to| address| ethical| concerns| surrounding| AI|,| ensuring| that| these| systems| align| with| soci|etal| values| and| do| not| pose| any| harm| or| risks| to| human| well|-|being|.| As| AI| continues| to| grow|,| it| is| essential| to| work| together| to| ensure| the| responsible| development| and| deployment| of| these| technologies| in| order| to| maximize| their| benefits| and| minimize| potential| negative| impacts|.| |||

# %%
buffer = ""
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    buffer += chunk.text
    if buffer.endswith((" ", ".", ",", "\n")):
        print(buffer, end="|", flush=True)
        buffer = ""
if buffer:
    print(buffer, end="|", flush=True)
# Out:
# Artificial Intelligence (AI) is a branch of computer science that aims to create intelligent machines capable of performing tasks that typically require human intelligence.| AI systems are designed to mimic human cognitive abilities,| including problem-solving,| reasoning,| learning,| perception,| and decision-making.|
# |
# |The development of AI began in the early |20th century,| and it has since evolved significantly.| Traditional AI,| also known as narrow AI,| refers to systems that are specifically designed to excel in a particular domain,| such as chess or speech recognition.| These AI systems employ rule-based systems,| decision trees,| and other logical approaches to perform tasks efficiently and accurately.|
# |
# |As technology advanced,| researchers turned their attention to artificial neural networks,| which are inspired by the human brain's structure and function.| These networks,| which consist of interconnected nodes or neurons,| are capable of learning and adapting to new data,| leading to the development of machine learning algorithms.|
# |
# |Machine learning algorithms enable AI systems to learn from experience,| improve over time,| and even make predictions or decisions without being explicitly programmed.| Deep learning,| a subfield of machine learning,| uses artificial neural networks with multiple layers to process and analyze complex data,| resulting in impressive achievements such as self-driving cars,| image recognition,| and natural language processing.|
# |
# |AI is now playing a significant role in various fields,| including healthcare,| finance,| education,| transportation,| and entertainment.| In healthcare,| AI-powered medical diagnosis and treatment planning have the potential to revolutionize the field,| improving patient outcomes and reducing costs.| In finance,| AI is used for fraud detection,| asset management,| and risk assessment.| Education sees AI applications in personalized learning,| adaptive curriculums,| and language translation.| In transportation,| AI is integrated into self-driving cars and traffic management systems.| Entertainment industries leverage AI for personalized recommendations,| virtual assistants,| and even the creation of original content.|
# |
# |However,| AI also raises concerns regarding job displacement,| ethical dilemmas,| and the potential for AI systems to surpass human decision-making abilities.| As AI continues to evolve,| it becomes crucial to ensure responsible development and implementation,| fostering collaboration between researchers,| policymakers,| and society at large to harness the power of AI while addressing its challenges and limitations.| |

# %% [markdown]
# ### Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots possess vibrant feathers primarily due to the factors below:\n\n1. Evolutionary Adaptation: In the wild, colorful feathers might have served as a form of camouflage to protect parrots from predators. Brightly colored feathers can make it harder for predators to spot their prey against various backgrounds.\n\n2. Display and Communication: Colorful feathers could also play a role in attracting mates and establishing dominance among parrots. These colors might indicate health, vitality, and fitness, making them more appealing to potential partners.\n\n3. Warning Signals: Parrots' bright colors might act as warning signals to potential predators. These predators have learned over time that consuming a parrot with bright colors may cause a negative reaction or make them sick, deterring them from hunting parrots in the future.\n\n4. Personal Expression: Parrots, like many birds, can exhibit personal expression through their feathers. Colors can communicate emotions, personality, or individual identity, allowing parrots to differentiate themselves from other birds in their group.\n\n5. Phototaxis: Some scientists believe that parrots' colorful feathers may be a result of a phenomenon called phototaxis. This is when birds are drawn to certain colors, such as blue and green, due to how light reflects off of their feathers and the environment around them.\n\nIt is essential to note that while these reasons have been proposed, scientists are still exploring and refining our understanding of the reasons behind parrots' colorful feathers. " additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 338, 'prompt_tokens': 18, 'total_tokens': 356, 'completion_time': 0.242132111, 'completion_tokens_details': None, 'prompt_time': 0.001058023, 'prompt_tokens_details': None, 'queue_time': 0.208036383, 'total_time': 0.243190134}, 'model_name': 'allam-2-7b', 'system_fingerprint': 'fp_ff744b2c7a', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a0254e-f598-7df2-b6d2-2c8662551900-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 18, 'output_tokens': 338, 'total_tokens': 356}
# content="Airplanes are designed to take advantage of the principle of lift, which is a fundamental concept in aerodynamics. Lift occurs when an object, such as an airplane wing, moves through air and creates a pressure difference between the top and bottom surfaces. The air pressure below the wing is lower, creating a suction that pulls the wing and airplane upward. This lift allows airplanes to gain altitude and maintain flight.\n\nHere is a simplified explanation of how airplanes fly:\n\n1. The shape of the wing is designed to create lift by having a curved upper surface known as an airfoil. This curve is essential for directing the air molecules moving over the wing in a way that creates lower pressure below the wing and higher pressure above.\n2. When the airplane moves through the air, its wings experience lift because of the pressure difference mentioned earlier.\n3. The wings are connected to the fuselage (the main body of the airplane) via strong beams called cabanes or spars. This connection provides stability and strength to the airplane.\n4. To control the airplane's flight, pilots use control surfaces, including the ailerons (small flaps on the wings that move side to side), the elevator (a vertical surface at the back of the fuselage that moves up and down), and the rudder (a vertical surface on the rear of the fuselage that moves left and right).\n5. Ailerons help control the airplane's roll, allowing it to turn by tilting the wing's angle of attack, which changes the airflow over the wing.\n6. The elevator allows pilots to adjust the airplane's pitch (forward or backward tilt) to alter its altitude.\n7. The rudder helps steer the airplane by adjusting the angle between the tail and the fuselage, affecting the airflow over the rear of the fuselage.\n8. Engines provide the necessary thrust to propel the airplane forward. The engines can be either propeller-powered or jet-powered.\n9. Ailerons, elevators, and rudders work together to control the airplane's movements in three-dimensional space.\n10. The airplane's wings provide stability and maintain a consistent angle of attack, which allows the airplane to fly smoothly and efficiently.\n\nIn summary, airplanes fly primarily due to the lift generated by the wings' curved airfoil shape. Pilots use control surfaces to steer, maneuver, and maintain altitude, while engines provide thrust to enable airspeed and lift the airplane off the ground. " additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 558, 'prompt_tokens': 13, 'total_tokens': 571, 'completion_time': 0.398902915, 'completion_tokens_details': None, 'prompt_time': 0.001032093, 'prompt_tokens_details': None, 'queue_time': 0.207509453, 'total_time': 0.399935008}, 'model_name': 'allam-2-7b', 'system_fingerprint': 'fp_ff744b2c7a', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a0254e-f59d-7f73-af44-2a2b92ad5629-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 558, 'total_tokens': 571}
# content='Quantum computing is a type of computing that utilizes quantum-mechanical phenomena, such as superposition and quantum entanglement, to process information. Traditional computers use bits to store and process information, which can be either a 0 or a 1. In contrast, quantum computers use quantum bits, or qubits, which can represent 0, 1, or both simultaneously due to superposition.\n\nThis property, known as quantum parallelism, allows quantum computers to perform certain calculations exponentially faster than classical computers in certain domains, such as cryptography, optimization, and simulation. For example, quantum computers could potentially crack encrypted codes used in secure communication, or simulate complex chemical reactions that are difficult for classical computers to handle.\n\nQuantum computing is still a relatively new field and is currently in the stage of development. Although early quantum computers exist, they are limited in size and capabilities, and it remains to be seen how practical quantum computers will be in the future. ' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 206, 'prompt_tokens': 12, 'total_tokens': 218, 'completion_time': 0.147414979, 'completion_tokens_details': None, 'prompt_time': 0.000995654, 'prompt_tokens_details': None, 'queue_time': 0.208300802, 'total_time': 0.148410633}, 'model_name': 'allam-2-7b', 'system_fingerprint': 'fp_ff744b2c7a', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a0254e-f5a3-7891-b646-f379a9de0178-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 206, 'total_tokens': 218}

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots possess vibrant feathers primarily due to natural selection and their unique role in the ecosystem. Colorful feathers serve several purposes for parrots:\n\n1. Communication: Parrots use their vivid colors and patterns to communicate with each other, especially during mating season. Different colors and markings can signify dominance, attract potential mates, or warn off rival males.\n\n2. Warning: Some bright colors, such as red, can warn predators that the parrot is toxic due to their diet. Insects and seeds consumed by parrots may contain chemicals that are unpalatable or even poisonous to predators. By appearing toxic, these colorful parrots deter predators from attacking them.\n\n3. Display: Parrots can also use their colorful feathers to display their healthiness and overall well-being to potential mates or rivals. Bright colors indicate a healthy bird, indicating that it has access to abundant food sources.\n\n4. Camouflage: In some species, especially when they're young or in certain environments, parrots can change their feather colors to blend in with their surroundings for better protection from predators.\n\n5. Mimicry: Many parrot species have evolved to mimic the colors and patterns of their environments, such as trees, flowers, or rocks, to blend in and avoid detection by predators.\n\nThese colorful feathers are also essential for thermoregulation, helping parrots regulate their body temperature in various climates. Overall, bright colors and patterns serve as a combination of communication, warning, and camouflage to aid parrots in their survival and reproductive success. ", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 359, 'prompt_tokens': 18, 'total_tokens': 377, 'completion_time': 0.263804898, 'completion_tokens_details': None, 'prompt_time': 0.001048793, 'prompt_tokens_details': None, 'queue_time': 0.200150617, 'total_time': 0.264853691}, 'model_name': 'allam-2-7b', 'system_fingerprint': 'fp_ff744b2c7a', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0254f-a122-7490-bdf7-8ab606a05e10-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 359, 'total_tokens': 377}),
#  AIMessage(content="Airplanes fly due to a combination of physics principles, including lift, thrust, and drag. Here's a simplified explanation:\n\n1. Lift: Lift is a force that acts perpendicular to the airflow and pushes an object upwards. In the case of airplanes, their wings are designed with an airfoil shape that creates a pressure difference between the upper and lower surfaces. As the air flows over the wing, it moves faster over the upper surface, resulting in lower pressure. This pressure difference creates lift, which propels the airplane upward.\n\n2. Thrust: Thrust is the force generated by the airplane's engines that counteracts the weight of the aircraft and propels it forward. Airplane engines, usually jet engines or propellers, push air out of the back of the engine at a high speed, creating thrust that moves the airplane forward.\n\n3. Drag: Drag is the resistance that air molecules exert on an airplane as it moves through the air. To fly efficiently, airplanes must maintain a balance between lift and drag. To reduce drag, airplanes are designed with streamlined bodies and have lifting surfaces like wings and vertical stabilizers.\n\nTo maintain altitude, airplanes use a combination of lift, thrust, and sometimes slightly more lift than thrust to maintain a stable flight. When an airplane wants to ascend or descend, pilots adjust the angle of attack (the angle between the wing and the airflow) or the thrust output of the engines to generate more lift or overcome the drag.\n\nAirplanes also use various control surfaces, such as ailerons (wing flaps), elevator (vertical stabilizer), and rudder (horizontal stabilizer), to make adjustments in flight, allowing pilots to maneuver and steer the airplane. ", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 380, 'prompt_tokens': 13, 'total_tokens': 393, 'completion_time': 0.279314904, 'completion_tokens_details': None, 'prompt_time': 0.001051043, 'prompt_tokens_details': None, 'queue_time': 0.200732522, 'total_time': 0.280365947}, 'model_name': 'allam-2-7b', 'system_fingerprint': 'fp_ff744b2c7a', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0254f-a12b-7022-95d0-0c9e7efa26da-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 380, 'total_tokens': 393}),
#  AIMessage(content='Quantum computing is a type of computing that uses quantum-mechanical phenomena, such as superposition and interference, to perform operations on data. Traditional computers store and process information using bits, which can represent 0 or 1. In contrast, quantum computers use quantum bits, or qubits, which can represent 0, 1, or both simultaneously due to a phenomenon called superposition.\n\nThis ability of qubits to exist in multiple states at the same time allows quantum computers to perform certain calculations much faster than classical computers. Another crucial concept in quantum computing is entanglement, where the state of one qubit can be directly affected by the state of another qubit, even if they are separated by large distances.\n\nQuantum computing is a rapidly developing field with potential applications in areas like cryptography, optimization, drug discovery, and simulation. However, building and maintaining stable quantum systems is a significant challenge due to their sensitivity to environmental disturbances. Today, quantum computers are still in the early stages of development and are limited in size and complexity. But as the technology continues to advance, quantum computers may eventually revolutionize computing power and solve problems that are intractable for classical computers. ', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 248, 'prompt_tokens': 12, 'total_tokens': 260, 'completion_time': 0.177604077, 'completion_tokens_details': None, 'prompt_time': 0.000876185, 'prompt_tokens_details': None, 'queue_time': 0.201264503, 'total_time': 0.178480262}, 'model_name': 'allam-2-7b', 'system_fingerprint': 'fp_ff744b2c7a', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0254f-a12d-7e43-9b16-8e5d073bb1a7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 248, 'total_tokens': 260})]
